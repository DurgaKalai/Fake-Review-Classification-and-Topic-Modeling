# %% [markdown]
# ## Topic Modelling

# %%
#importing libraries
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation, NMF

# %%
#loading preprocessed data
data = pd.read_csv(r"C:\Users\DURGA\Desktop\final_project_fake_review\dataset\TP_DS.csv")

# %%
#The reviews variable will contain only the non-null review text
# Sample DataFrame (adjust the 'cleaned_text' column as needed)
reviews = data['cleaned_text'].dropna()  # Assuming 'data' is the DataFrame with review text

# %% [markdown]
# ###  Step 1: Text Vectorization with TF-IDF

# %%
#transforme your text data (reviews) into a numerical format (tfidf_matrix) suitable for further analysis or modeling.
tfidf_vectorizer = TfidfVectorizer(stop_words='english', max_features=1000)
tfidf_matrix = tfidf_vectorizer.fit_transform(reviews)

# %% [markdown]
# ### Step 2: LDA and NMF for Topic Modeling

# %%
#apply two different algorithms (LDA and NMF) to identify topics in your text data
n_topics = 100 # Number of topics

# LDA Model
lda_model = LatentDirichletAllocation(n_components=n_topics, random_state=42)
lda_topics = lda_model.fit_transform(tfidf_matrix)

# NMF Model
nmf_model = NMF(n_components=n_topics, random_state=42)
nmf_topics = nmf_model.fit_transform(tfidf_matrix)

# Helper function to get top words per topic
def get_top_words(model, feature_names, n_top_words=10):
    topics = {}
    for topic_idx, topic in enumerate(model.components_):
        top_words = [feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]
        topics[f"Topic {topic_idx + 1}"] = top_words
    return topics

# Get top words for each topic
lda_top_words = get_top_words(lda_model, tfidf_vectorizer.get_feature_names_out())
nmf_top_words = get_top_words(nmf_model, tfidf_vectorizer.get_feature_names_out())

print("LDA Topics:\n", lda_top_words)
print("NMF Topics:\n", nmf_top_words)
# Out:
# LDA Topics:
#  {'Topic 1': ['bed', 'pillow', 'cheap', 'cook', 'accur', 'feel', 'love', 'poor', 'look', 'use'], 'Topic 2': ['wrong', 'origin', 'finish', 'version', 'roll', 'varieti', 'memori', 'dead', 'prefer', 'separ'], 'Topic 3': ['reason', 'gave', 'star', 'bottl', 'plastic', 'small', 'good', 'drink', 'comfort', 'qualiti'], 'Topic 4': ['link', 'hook', 'class', 'data', 'ref', 'norm', 'nbsp', 'dp', 'utf8', 'href'], 'Topic 5': ['smell', 'thank', 'dri', 'outsid', 'wash', 'tree', 'backpack', 'use', 'unless', 'stuff'], 'Topic 6': ['babi', 'broken', 'advertis', 'assembl', 'replac', 'bought', 'easi', 'work', 'round', 'great'], 'Topic 7': ['pan', 'bulki', 'room', 'air', 'plenti', 'toe', 'live', 'import', 'comfort', 'fit'], 'Topic 8': ['novel', 'book', 'reader', 'read', 'chain', 'histor', 'stori', 'charact', 'john', 'author'], 'Topic 9': ['light', 'bright', 'bathroom', 'use', 'white', 'color', 'great', 'red', 'work', 'nice'], 'Topic 10': ['parti', 'trs', 'tini', 'smart', 'manag', 'trust', 'lower', 'surviv', 'use', 'work'], 'Topic 11': ['simpl', 'switch', 'everyon', 'tear', 'cost', 'woman', 'immedi', 'let', 'fairli', 'rest'], 'Topic 12': ['band', 'bar', 'adult', 'shop', 'break', 'watch', 'great', 'rubber', 'kid', 'size'], 'Topic 13': ['unit', 'model', 'tea', 'seal', 'compact', 'snap', 'oper', 'use', 'similar', 'work'], 'Topic 14': ['train', 'beauti', 'wooden', 'tabl', 'el', 'plate', 'magic', 'certainli', 'love', 'anyth'], 'Topic 15': ['touch', 'murder', 'talk', 'die', 'center', 'later', 'tablet', 'truli', 'person', 'work'], 'Topic 16': ['granddaught', 'love', 'music', 'old', 'huge', 'year', 'mat', 'great', 'fan', 'favorit'], 'Topic 17': ['wide', 'foot', 'width', 'fit', 'narrow', 'war', 'bore', 'comfort', 'perfect', 'littl'], 'Topic 18': ['glass', 'steel', 'tall', 'clean', 'kitchen', 'stainless', 'easi', 'use', 'bought', 'heavi'], 'Topic 19': ['money', 'worth', 'wast', 'pricey', 'valu', 'paid', 'apart', 'appreci', 'contain', 'forc'], 'Topic 20': ['door', 'glove', 'open', 'noth', 'tough', 'previou', 'close', 'futur', 'hand', 'work'], 'Topic 21': ['filter', 'litter', 'box', 'practic', 'soni', 'volum', 'water', 'use', 'cat', 'work'], 'Topic 22': ['tool', 'knife', 'sharp', 'use', 'slide', 'handl', 'blade', 'great', 'work', 'nice'], 'Topic 23': ['instruct', 'follow', 'clear', 'descript', 'total', 'step', 'easi', 'floor', 'mous', 'includ'], 'Topic 24': ['gift', 'shirt', 'bigger', 'expect', 'love', 'smaller', 'bought', 'wallet', 'littl', 'heavier'], 'Topic 25': ['book', 'charact', 'read', 'stori', 'develop', 'enjoy', 'written', 'good', 'author', 'love'], 'Topic 26': ['book', 'stori', 'charact', 'read', 'main', 'like', 'view', 'relationship', 'predict', 'point'], 'Topic 27': ['screen', 'function', 'keyboard', 'headphon', 'appear', 'use', 'non', 'sound', 'surfac', 'mous'], 'Topic 28': ['watch', 'tv', 'bunch', 'stop', 'otherwis', 'leather', 'list', 'half', 'work', 'love'], 'Topic 29': ['cute', 'super', 'sock', 'christma', 'present', 'adapt', 'cool', 'disc', 'hit', 'machin'], 'Topic 30': ['pocket', 'carri', 'strap', 'card', 'throw', 'sheet', 'bag', 'pack', 'great', 'use'], 'Topic 31': ['son', 'love', 'grandson', 'play', 'christma', 'toy', 'daughter', 'bought', 'absolut', 'old'], 'Topic 32': ['cold', 'ok', 'warm', 'weather', 'bra', 'hot', 'sometim', 'use', 'great', 'water'], 'Topic 33': ['updat', 'save', 'sight', 'fail', 'track', 'power', 'review', 'use', 'work', 'replac'], 'Topic 34': ['lead', 'femal', 'grow', 'lack', 'book', 'german', 'publish', 'strong', 'charact', 'god'], 'Topic 35': ['dress', 'fit', 'materi', 'fabric', 'size', 'larg', 'medium', 'waist', 'pair', 'soft'], 'Topic 36': ['summer', 'cloth', 'standard', 'pro', 'gone', 'use', 'size', 'bought', 'perfect', 'love'], 'Topic 37': ['pad', 'knee', 'cup', 'key', 'somewhat', 'mouth', 'wide', 'fit', 'littl', 'nice'], 'Topic 38': ['len', 'bike', 'project', 'camera', 'use', 'element', 'ride', 'good', 'great', 'qualiti'], 'Topic 39': ['father', 'town', 'school', 'book', 'mark', 'stori', 'frame', 'titl', 'read',  ...
# NMF Topics:
#  {'Topic 1': ['book', 'write', 'finish', 'histori', 'inform', 'forward', 'start', 'disappoint', 'copi', 'kept'], 'Topic 2': ['use', 'camera', 'fact', 'phone', 'issu', 'week', 'trs', 'pad', 'job', 'car'], 'Topic 3': ['movi', 'act', 'action', 'seen', 'funni', 'saw', 'entertain', 'plot', 'actor', 'slow'], 'Topic 4': ['love', 'fact', 'absolut', 'wife', 'music', 'granddaught', 'grandson', 'husband', 'mi', 'charact'], 'Topic 5': ['fit', 'perfectli', 'tight', 'snug', 'dress', 'fine', 'loo', 'head', 'short', 'waist'], 'Topic 6': ['dog', 'treat', 'chew', 'collar', 'har', 'mi', 'chewer', 'ear', 'eat', 'leash'], 'Topic 7': ['stori', 'told', 'line', 'short', 'sweet', 'act', 'flow', 'point', 'romanc', 'pace'], 'Topic 8': ['great', 'thi', 'job', 'valu', 'deal', 'addit', 'kid', 'wish', 'money', 'purchase'], 'Topic 9': ['good', 'act', 'veri', 'write', 'valu', 'far', 'nic', 'bad', 'overal', 'money'], 'Topic 10': ['toy', 'chew', 'favorit', 'child', 'durabl', 'ball', 'togeth', 'babi', 'grandson', 'puppi'], 'Topic 11': ['light', 'bright', 'weight', 'led', 'night', 'flashlight', 'switch', 'room', 'hous', 'dark'], 'Topic 12': ['like', 'fact', 'felt', 'style', 'll', 'short', 'tast', 'ok', 'pictur', 'adjust'], 'Topic 13': ['work', 'fine', 'advertis', 'perfectli', 'instal', 'cabl', 'nic', 'stop', 'comput', 'issu'], 'Topic 14': ['bulb', 'bright', 'led', 'instal', 'kitchen', 'lamp', 'warm', 'white', 'room', 'downsid'], 'Topic 15': ['life', 'peopl', 'woman', 'live', 'famili', 'man', 'world', 'help', 'real', 'new'], 'Topic 16': ['plastic', 'cover', 'solid', 'hold', 'lid', 'hard', 'cheap', 'clear', 'metal', 'durabl'], 'Topic 17': ['read', 'quick', 'definit', 'forward', 'day', 'glad', 'middl', 'admit', 'night', 'fast'], 'Topic 18': ['reason', 'gave', 'star', 'cover', 'rate', 'flimsi', 'self', 'practic', 'given', 'slightli'], 'Topic 19': ['nice', 'addit', 'touch', 'solid', 'veri', 'design', 'finish', 'extra', 'fabric', 'collect'], 'Topic 20': ['realli', 'vacuum', 'problem', 'help', 'cute', 'actual', 'cool', 'impress', 'stand', 'bad'], 'Topic 21': ['littl', 'tight', 'pricey', 'wish', 'smaller', 'guy', 'difficult', 'big', 'loo', 'slow'], 'Topic 22': ['product', 'plea', 'link', 'ship', 'happi', 'compani', 'design', 'receiv', 'arriv', 'issu'], 'Topic 23': ['year', 'old', 'granddaught', 'ago', 'grandson', 'new', 'lab', 'sever', 'older', 'mani'], 'Topic 24': ['cat', 'treat', 'litter', 'picki', 'eat', 'smell', 'scratch', 'stuff', 'hous', 'pet'], 'Topic 25': ['size', 'larger', 'smaller', 'normal', 'true', '10', 'half', 'big', 'bigger', 'run'], 'Topic 26': ['easi', 'clean', 'instal', 'assembl', 'instruct', 'follow', 'togeth', 'super', 'carri', 'adjust'], 'Topic 27': ['time', 'arriv', 'everi', 'wast', 'sever', 'hard', 'saw', 'favorit', 'second', 'describ'], 'Topic 28': ['charact', 'develop', 'plot', 'believ', 'main', 'write', 'kept', 'told', 'storylin', 'flow'], 'Topic 29': ['turn', 'twist', 'amaz', 'plot', 'page', 'mani', 'screen', 'button', 'switch', 'power'], 'Topic 30': ['shoe', 'foot', 'heel', 'toe', 'walk', 'support', 'return', 'worn', 'run', 'slightli'], 'Topic 31': ['look', 'forward', 'pictur', 'exactli', 'cheap', 'someth', 'lamp', 'bathroom', 'room', 'kitchen'], 'Topic 32': ['piec', 'puzzl', 'togeth', 'wood', 'assembl', 'contain', 'kid', 'tini', 'broke', 'solid'], 'Topic 33': ['seri', 'forward', 'favorit', 'continu', 'second', 'start', 'new', 'hope', 'entir', 'season'], 'Topic 34': ['small', 'come', 'screw', 'driver', 'problem', 'big', 'run', 'town', 'tight', 'space'], 'Topic 35': ['lot', 'action', 'hold', 'inform', 'stuff', 'heart', 'differ', 'sexual', 'fact', 'suspens'], 'Topic 36': ['set', 'train', 'second', 'glass', 'togeth', 'sheet', 'anoth', 'wooden', 'includ', 'instruct'], 'Topic 37': ['recommend', 'anyon', 'highli', 'definit', 'thi', 'histori', 'everyon', 'histor', 'solid', 'mysteri'], 'Topic 38': ['perfect', 'condit', 'exactli', 'kitchen', 'warm', 'arriv', 'summer', 'soft', 'addit', 'length'], 'Topic 39': ['qualiti', 'high', 'plea', 'amaz', 'poor', ' ...

# %%
import pickle

# Save models and vectorizer
with open('lda_model.pkl', 'wb') as f:
    pickle.dump(lda_model, f)
with open('nmf_model.pkl', 'wb') as f:
    pickle.dump(nmf_model, f)
with open('tfidf_vectorizer.pkl', 'wb') as f:
    pickle.dump(tfidf_vectorizer, f)

# %% [markdown]
# ### Topic Modeling, Clustering (K-Means), and Visualization (PCA & t-SNE)

# %%
#performing topic modeling, followed by clustering (via K-Means) and visualizing the results using PCA and t-SNE.

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans, DBSCAN
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
# Load Data
data = pd.read_csv(r"C:\Users\DURGA\Desktop\final_project_fake_review\dataset\TP_DS.csv")
reviews = data['cleaned_text'].dropna()

# %% [markdown]
# #### #Step 1: Text Vectorization with TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(stop_words='english', max_features=1000)
tfidf_matrix = tfidf_vectorizer.fit_transform(reviews)

# %% [markdown]
# #### # Step 2: LDA and NMF for Topic Modeling

# %%
from sklearn.decomposition import LatentDirichletAllocation, NMF
n_topics = 100

# %%
# LDA Model
lda_model = LatentDirichletAllocation(n_components=n_topics, random_state=42)
lda_topics = lda_model.fit_transform(tfidf_matrix)

# %% [markdown]
# #### #step 3: Apply K-Means Clustering on Topic Model Features

# %%
num_clusters = 5
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans_labels = kmeans.fit_predict(lda_topics)  # Using LDA topic distribution for clustering

# %% [markdown]
# #### # Step 4: Visualize Clusters using PCA or t-SNE

# %%
# Using PCA for dimensionality reduction
pca = PCA(n_components=2)
pca_components = pca.fit_transform(lda_topics)

plt.figure(figsize=(10, 7))
plt.scatter(pca_components[:, 0], pca_components[:, 1], c=kmeans_labels, cmap='plasma', s=15)
plt.title("K-Means Clustering of Reviews (PCA)")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.colorbar(label="Cluster")
plt.show()

# %%
# Using t-SNE for dimensionality reduction (optional)
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
tsne_components = tsne.fit_transform(lda_topics)

plt.figure(figsize=(10, 7))
plt.scatter(tsne_components[:, 0], tsne_components[:, 1], c=kmeans_labels, cmap='viridis', s=25)
plt.title("K-Means Clustering of Reviews (t-SNE)")
plt.xlabel("t-SNE Component 1")
plt.ylabel("t-SNE Component 2")
plt.colorbar(label="Cluster")
plt.show()
